# %% [markdown]
# # Lab: Building a Reproducible Analysis Workflow
#
# In the first part of this lab, you will use official National Park Service data to answer a guided question. In the second part, you will find a dataset and conduct an analysis of your own.
#
# Use the workflow from lecture throughout the lab:
#
# 1. **Question**
# 2. **Data**
# 3. **Operation**
# 4. **Check**
# 5. **Evidence**
# 6. **Conclusion**
# 7. **Limitation**

# %% [markdown]
# ## Learning goals
#
# By the end of this lab, you should be able to:
#
# - organize an investigation with the reproducible analysis workflow;
# - inspect a dataset before analyzing it;
# - group, summarize, check, and sort observations with Pandas;
# - formulate a research question that can be answered with data; and
# - distinguish evidence, conclusions, and limitations.

# %% [markdown]
# ## Using AI tools responsibly
#
# You may use AI to ask questions, debug code, or receive feedback. You remain responsible for understanding your work, verifying suggestions against the data, and citing the source of your dataset. At the end, disclose whether you used an AI tool. Using AI is not required.

# %% [markdown]
# # Part 1: Florida park visitation

# %% [markdown]
# ## Background
#
# The National Park Service (NPS) publishes estimates of recreational visits to its units. These estimates help parks understand patterns in public use and plan staffing, maintenance, transportation, and visitor services.
#
# This course file contains monthly estimates for five Florida NPS units from 2015 through 2025:
#
# - Big Cypress National Preserve
# - Biscayne National Park
# - Canaveral National Seashore
# - Dry Tortugas National Park
# - Everglades National Park
#
# A recreational visit is a visit, not necessarily one unique person. A person who visits several times may be counted several times.

# %% [markdown]
# | Feature | Description |
# | --- | --- |
# | `park_code` | Four-letter NPS unit code |
# | `park` | Name of the NPS unit |
# | `year` | Calendar year of the observation |
# | `month_number` | Month represented as an integer from 1 through 12 |
# | `month` | Month name |
# | `recreation_visits` | Estimated recreational visits during that park-month |

# %% [markdown]
# ## Step 1: Question
#
# **After the decline in July 2020, when did Canaveral National Seashore's July recreational visitation first return to or exceed its average July visitation from 2015–2019?**
#
# The 2015–2019 mean provides a pre-pandemic comparison point. In this question, “recovery” means the first July from 2020 onward with visitation at or above that baseline. This definition does not require every later July to remain above the baseline.

# %% [markdown]
# ## Step 2: Data
#
# Import Pandas using the alias `pd`. Read `data/nps_florida_park_visitation_2015_2025.csv` into a DataFrame named `park_visits`, then display its first five rows.

# %%
# Write your code here.
import pandas as pd

park_visits = pd.read_csv('data/nps_florida_park_visitation_2015_2025.csv')

park_visits.head()
# Out:
#   park_code                           park  year  month_number     month  \
# 0      BICY  Big Cypress National Preserve  2015             1   January
# 1      BICY  Big Cypress National Preserve  2015             2  February
# 2      BICY  Big Cypress National Preserve  2015             3     March
# 3      BICY  Big Cypress National Preserve  2015             4     April
# 4      BICY  Big Cypress National Preserve  2015             5       May
#
#    recreation_visits
# 0             114045
# 1             144112
# 2             153084
# 3             113880
# 4              72510

# %% [markdown]
# Display the last five rows.

# %%
# Write your code here.
park_visits.tail()
# Out:
#     park_code                      park  year  month_number      month  \
# 655      EVER  Everglades National Park  2025             8     August
# 656      EVER  Everglades National Park  2025             9  September
# 657      EVER  Everglades National Park  2025            10    October
# 658      EVER  Everglades National Park  2025            11   November
# 659      EVER  Everglades National Park  2025            12   December
#
#      recreation_visits
# 655              50464
# 656              32290
# 657              19008
# 658              53416
# 659              70926

# %% [markdown]
# Display information about the DataFrame and calculate the number of missing observations in each feature.

# %%
# Write your code here.
park_visits.info()

park_visits.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   park_code          660 non-null    str
#  1   park               660 non-null    str
#  2   year               660 non-null    int64
#  3   month_number       660 non-null    int64
#  4   month              660 non-null    str
#  5   recreation_visits  660 non-null    int64
# dtypes: int64(3), str(3)
# memory usage: 54.1 KB
# park_code            0
# park                 0
# year                 0
# month_number         0
# month                0
# recreation_visits    0
# dtype: int64

# %% [markdown]
# **What does each row represent?**
#
# Your answer: Total estimated recreational visits for one specific park during a specific month and year.

# %% [markdown]
# **Are any observations missing from the six features?**
#
# Your answer: No, none are missing.

# %% [markdown]
# ## Step 3: Operation
#
# Create one Boolean condition that identifies Canaveral National Seashore and another that identifies July.

# %%
# Write your code here.
canaveral = park_visits['park'] == 'Canaveral National Seashore'

july = park_visits['month'] == 'July'

# %% [markdown]
# Combine the two conditions with `&`. Use `.loc` to select the `year` and `recreation_visits` features, make a copy named `canaveral_july`, and display it.

# %%
# Write your code here.
canaveral_july = park_visits.loc[canaveral & july, ['year', 'recreation_visits']].copy()
canaveral_july
# Out:
#      year  recreation_visits
# 270  2015             163169
# 282  2016             216437
# 294  2017             138018
# 306  2018             189285
# 318  2019             162947
# 330  2020             112898
# 342  2021             206636
# 354  2022             233352
# 366  2023             173296
# 378  2024             176242
# 390  2025             253403

# %% [markdown]
# Create `pre_pandemic_condition`, which is `True` for years from 2015 through 2019. Use it with `.loc` to calculate the mean of `recreation_visits`, and store the result as `pre_pandemic_july_mean`.
#
# Display `pre_pandemic_july_mean`.

# %%
# Write your code here.
pre_pandemic_condition = (canaveral_july['year'] >=2015) & (canaveral_july['year'] <=2019)
pre_pandemic_july_mean = canaveral_july.loc[pre_pandemic_condition, 'recreation_visits'].mean()
print(pre_pandemic_july_mean)
# Out:
# 173971.2

# %% [markdown]
# Create a condition that identifies rows from 2020 onward whose `recreation_visits` are greater than or equal to `pre_pandemic_july_mean`. Use `.loc` to create `recovery_years`, then display it in ascending year order.

# %%
# Write your code here.
after_2020 = canaveral_july['year'] >=2020
greater_or_equal_mean = canaveral_july['recreation_visits'] >=pre_pandemic_july_mean
recovery_years = canaveral_july.loc[after_2020 & greater_or_equal_mean].sort_values(by='year',ascending=True)
recovery_years
# Out:
#      year  recreation_visits
# 342  2021             206636
# 354  2022             233352
# 378  2024             176242
# 390  2025             253403

# %% [markdown]
# ## Step 4: Check
#
# Display the number of rows in `canaveral_july`, its smallest year, and its greatest year.

# %%
# Write your code here.
canaveral_july.describe()
# Out:
#               year  recreation_visits
# count    11.000000          11.000000
# mean   2020.000000      184153.000000
# std       3.316625       41311.472719
# min    2015.000000      112898.000000
# 25%    2017.500000      163058.000000
# 50%    2020.000000      176242.000000
# 75%    2022.500000      211536.500000
# max    2025.000000      253403.000000

# %% [markdown]
# **Do these results confirm that the filtered data contains one July observation for every year from 2015 through 2025?**
#
# Your answer: Yes the count was 11 so there was one for every year including 2025.

# %% [markdown]
# Count the observations used to calculate `pre_pandemic_july_mean`.

# %%
# Write your code here.
print(canaveral_july.loc[pre_pandemic_condition, 'recreation_visits'].count())
# Out:
# 5

# %% [markdown]
# **Does the baseline use the expected five years?**
#
# Your answer: Yes the count was 5 which represents the years 2015, 2016, 2017, 2018, and 2019

# %% [markdown]
# ## Step 5: Evidence
#
# Display the first row of `recovery_years`.

# %%
# Write your code here.
recovery_years.head(1)
# Out:
#      year  recreation_visits
# 342  2021             206636

# %% [markdown]
# **What was the 2015–2019 mean, and which year first met or exceeded it after the July 2020 decline? Report that year's July visitation.**
#
# Your answer: The mean for 2015-2019 was 173971.2 visits. The first year to meet or exceed tha number was 2021 with 206636 visits.

# %% [markdown]
# ## Step 6: Conclusion

# %% [markdown]
# **Write one sentence that answers the research question using the evidence.**
#
# Your answer: After the decline in July of 2020, Canaveral National Seashore's July recreational visitation first returned to or exceeded its average in 2021.

# %% [markdown]
# ## Step 7: Limitation

# %% [markdown]
# **Does first exceeding the baseline mean that every later July remained above it? Use the data to explain.**
#
# Your answer: No. Looking at the data, July of 2023 there were 173296 visits which was slightly below the baseline, meaning visitation dipped back down after the 2021 recovery.

# %% [markdown]
# **Why does this analysis alone not establish that the pandemic caused the 2020 decline?**
#
# Your answer:This data only shows visitation, not why they visited or not. There could be factors like the weather, for example, that are not factored in here.

# %% [markdown]
# # Part 2: Your own investigation

# %% [markdown]
# ## Find a dataset
#
# Find a CSV dataset that interests you. Kaggle is one possible source, but you may use another reputable source. Choose a dataset that:
#
# - has a clearly identified publisher or creator;
# - includes documentation explaining the observations and features;
# - contains at least one categorical and one quantitative feature;
# - is appropriate to share in a class assignment;
# - does not contain private or personally identifying information; and
# - is small enough to run comfortably in this notebook.
#
# Save the CSV in the notebook's `data` folder before continuing.

# %% [markdown]
# **What is the dataset's title, publisher or creator, and direct source URL?**
#
# Your answer: Best-Selling Steam Games of All Time, H. Buğra Eken, https://www.kaggle.com/datasets/hbugrae/best-selling-steam-games-of-all-time

# %% [markdown]
# **What does one row represent?**
#
# Your answer: A unique top selling game on steam as of June 2025.

# %% [markdown]
# ## Step 1: Question
#
# Formulate one research question that can be answered with your dataset. The question must require a calculation or comparison, not merely looking up one value.

# %% [markdown]
# **What is your research question?**
#
# Your answer: Which age restriction category (0, 10, 13, or 17) has the highest average gameplay length?

# %% [markdown]
# ## Step 2: Data
#
# Read your CSV into a clearly named DataFrame. Display the first and last five rows, information about the DataFrame, and the missing-value count for every feature.

# %%
# Write your code here.
steam_data = pd.read_csv('data/bestSelling_games.csv')
steam_data.head()
# Out:
#                 game_name  reviews_like_rate  all_reviews_number  \
# 0        Counter-Strike 2                 86             8803754
# 1     PUBG: BATTLEGROUNDS                 59             2554482
# 2   ELDEN RING NIGHTREIGN                 77               53426
# 3  The Last of Us™ Part I                 79               45424
# 4   Red Dead Redemption 2                 92              672140
#
#    release_date           developer  \
# 0  21 Aug, 2012               Valve
# 1  21 Dec, 2017    PUBG Corporation
# 2  30 May, 2025  FromSoftware, Inc.
# 3  28 Mar, 2023     Naughty Dog LLC
# 4   5 Dec, 2019      Rockstar Games
#
#                                    user_defined_tags supported_os  \
# 0                              FPS, Action, Tactical   win, linux
# 1                Survival, Shooter, Action, Tactical          win
# 2               Souls-like, Open World, Fantasy, RPG          win
# 3              Story Rich, Shooter, Survival, Horror          win
# 4  Open World, Story Rich, Adventure, Realistic, ...          win
#
#                                  supported_languages  price  \
# 0  English, Czech, Danish, Dutch, Finnish, French...   0.00
# 1  English, Korean, Simplified Chinese, French, G...   0.00
# 2  English, Japanese, French, Italian, German, Sp...  25.99
# 3  English, Italian, Spanish - Spain, Czech, Dutc...  59.99
# 4  English, French, Italian, German, Spanish - Sp...  59.99
#
#                                       other_features  age_restriction  rating  \
# 0  Cross-Platform Multiplayer, Steam Trading Card...               17    3.20
# 1  Online PvP, Stats, Remote Play on Phone, Remot...               13    3.10
# 2  Single-player, Online Co-op, Steam Achievement...               17    3.96
# 3  Single-player, Steam Achievements, Steam Tradi...               17    4.10
# 4  Single-player, Online PvP, Online Co-op, Steam...               17    4.32
#
#    difficulty  length  estimated_downloads
# 0           4      80            306170000
# 1           4      73            162350000
# 2           4      50               840000
# 3           3      24              2000000
# 4           3      80             21610000

# %%
steam_data.tail()
# Out:
#                  game_name  reviews_like_rate  all_reviews_number  \
# 2375          Wooden House                 38                 147
# 2376  Shoot. Push. Repeat.                 84                  65
# 2377        X2: The Threat                 83                 416
# 2378              !AnyWay!                 71                 498
# 2379        UBERMOSH:OMEGA                 93                 314
#
#      release_date       developer       user_defined_tags supported_os  \
# 2375  5 Sep, 2016         GDNomaD              Simulation          win
# 2376  8 Jun, 2020         CrewLab              Puzzle, 2D          win
# 2377  3 Dec, 2003         Egosoft    Strategy, Simulation          win
# 2378  6 Jun, 2018        EYEFRONT          Platformer, 2D          win
# 2379  8 Nov, 2019  Walter Machado  Action, Pixel Graphics          win
#
#                                     supported_languages  price  \
# 2375                                            English   0.89
# 2376  English, French, Italian, German, Spanish - Sp...   0.89
# 2377  English, French, German, Italian, Spanish - Sp...   2.99
# 2378  English, Russian, French, Italian, German, Pol...   1.35
# 2379  English, French, Italian, German, Spanish - Sp...   0.89
#
#                                          other_features  age_restriction  \
# 2375  Single-player, Steam Trading Cards, Family Sha...               17
# 2376  Single-player, Steam Achievements, Steam Cloud...                0
# 2377  Single-player, Captions available, Steam Cloud...               13
# 2378  Single-player, Steam Achievements, Steam Tradi...                0
# 2379  Single-player, Steam Achievements, Family Sharing               13
#
#       rating  difficulty  length  estimated_downloads
# 2375    1.24           3       1               221000
# 2376    3.64           1       3                 2700
# 2377    3.61           4      60                47500
# 2378    3.00           3       2                79000
# 2379    4.17           5      12                14000

# %%
steam_data.info()
steam_data.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2380 entries, 0 to 2379
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   game_name            2380 non-null   str
#  1   reviews_like_rate    2380 non-null   int64
#  2   all_reviews_number   2380 non-null   int64
#  3   release_date         2380 non-null   str
#  4   developer            2380 non-null   str
#  5   user_defined_tags    2380 non-null   str
#  6   supported_os         2380 non-null   str
#  7   supported_languages  2380 non-null   str
#  8   price                2380 non-null   float64
#  9   other_features       2380 non-null   str
#  10  age_restriction      2380 non-null   int64
#  11  rating               2380 non-null   float64
#  12  difficulty           2380 non-null   int64
#  13  length               2380 non-null   int64
#  14  estimated_downloads  2380 non-null   int64
# dtypes: float64(2), int64(6), str(7)
# memory usage: 942.5 KB
# game_name              0
# reviews_like_rate      0
# all_reviews_number     0
# release_date           0
# developer              0
# user_defined_tags      0
# supported_os           0
# supported_languages    0
# price                  0
# other_features         0
# age_restriction        0
# rating                 0
# difficulty             0
# length                 0
# estimated_downloads    0
# dtype: int64

# %% [markdown]
# **Which observations and features will you use to answer your question?**
#
# Your answer: I will use `age_restriction` to group the names and `length` to calculate average play time. I will also use `game_name` to count the number of games in each category.

# %% [markdown]
# ## Step 3: Operation
#
# Write the code needed to prepare, filter, group, summarize, or sort the data. Store the final evidence in a clearly named object and display it.

# %%
# Write your code here.
age_summary = (steam_data.groupby('age_restriction')
    .agg(game_count=('game_name', 'count'), mean_of_length=('length', 'mean'))
    .sort_values('mean_of_length', ascending=False))

age_summary
# Out:
#                  game_count  mean_of_length
# age_restriction
# 13                      620       26.311290
# 10                      455       25.221978
# 17                      743       21.148048
# 0                       562       19.848754

# %% [markdown]
# **Explain how your operations connect the selected data to your research question.**
#
# Your answer: Grouping the data by `age_restriction` I was able to create groups based on Everyone, 10+, 13+, and 17+ rated games. Then with `.agg()` I calculated the average length in hours for each rating, and finally sorting in descending places the age group with the highest average playtime at the top of the list.

# %% [markdown]
# ## Step 4: Check
#
# Write at least one check that could reveal an error in your analysis, then display its result.

# %%
# Write your code here.
max_length = steam_data['length'].max()
print(max_length)
# Out:
# 80

# %% [markdown]
# **What did you check, and did the result meet your expectation?**
#
# Your answer: I checked the max value for length to see if it was actually capped at 80 hours. Since the data set stated "the value is capped at a maximum of 80 hours". If this was incorrect it could have created an error in my analysis.

# %% [markdown]
# ## Step 5: Evidence

# %% [markdown]
# **Which specific value or comparison in your output answers the question?**
#
# Your answer: `age_restriction` 13 `game_count` 620 	`mean_of_length` 26.311290

# %% [markdown]
# ## Step 6: Conclusion

# %% [markdown]
# **What conclusion is supported by the evidence?**
#
# Your answer: Games with an age restriction of 13+ have the highest average playtime at 26.311290 hours.

# %% [markdown]
# ## Step 7: Limitation

# %% [markdown]
# **What should a reader avoid concluding from your analysis, and why?**
#
# Your answer: A reader should avoid concluding that this represents the exact average playtime of all Steam games. This dataset only includes the top 2,380 BEST-SELLING games. Also, the dataset `length` data was pulled from GameFAQs and manually estimated when length was missing, meaning this could be average completion times and not exact, tracked playtime.

# %% [markdown]
# ## AI-use reflection

# %% [markdown]
# **State whether you used an AI tool. If you did, describe one suggestion you checked and what you accepted, changed, or rejected. If you did not, state that you did not use one.**
#
# Your response:
# - Tool used: Gemini
# - What I asked it to help with: Spelling and to brainstorm a research question for the dataset I choose.
# - One suggestion I checked against my code, chart, or output: It actually gave me a few options for a good research question I kind of put some together to come up with the question I arrived at.
# - What I accepted, modified, or rejected—and why: I modified the ideas it gave me for a good research question.

# %% [markdown]
# ## Submission checklist
#
# Before submitting, confirm that all cells run in order, the independent dataset and its source are included, every answer is complete, numerical claims match the output, conclusions are appropriately limited, and the AI-use reflection is complete.
